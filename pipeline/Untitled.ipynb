# %%
import pandas as pd

# %%
pd.__file__
# Out:
# '/workspaces/data-engineering-zcmp-docker/pipeline/.venv/lib/python3.13/site-packages/pandas/__init__.py'

# %%
prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc'
url = f'{prefix}/taxi_zone_lookup.csv'

# %%
df = pd.read_csv(url,nrows=10)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [LocationID, Borough, Zone, service_zone]
# Index: []

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df,name='zone', con=engine))
# Out:
# CREATE TABLE zone (
# 	"LocationID" BIGINT,
# 	"Borough" TEXT,
# 	"Zone" TEXT,
# 	service_zone TEXT
# )
